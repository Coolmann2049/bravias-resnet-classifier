# %%
# !git clone https://github.com/Coolmann2049/bravias-resnet-classifier.git
# %cd bravias-resnet-classifier
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'bravias-resnet-classifier'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 28 (delta 13), reused 24 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 37.29 KiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /kaggle/working/bravias-resnet-classifier
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 16.7 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 62.2 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 86.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# !python data_generator.py --n_samples 500000 --numpy
#!python data_loader.py --n_per_class 10000
# Out:
# [data_generator] Backend: NUMPY (no pymatgen)
# [data_generator] Generating 500,000 patterns (35714/class + 4 extra) …
# Bravais class: 100%|█████████████████████████| 14/14 [1:55:44<00:00, 496.03s/it]
# [dataset] Saved → data/processed/dataset.npz  (1400.8 MB)
# [data_generator] Done ✓  X=(500000, 1024)  y=(500000,)

# %%
#!git pull origin main

# !python train.py --model small --epochs 20 --batch 256 --lr 3e-4 --dropout 0.5
# Out:
# 2026-04-14 20:21:13.989934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776198074.015888    1340 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776198074.024619    1340 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776198074.045857    1340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from IPython.display import Image
Image('outputs/plots/training_curves.png')
display(Image('outputs/plots/training_curves.png'))
display(Image('outputs/plots/confusion_matrix.png'))
